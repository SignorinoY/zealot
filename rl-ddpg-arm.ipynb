# %%
from reinforcement_learning.deep_deterministic_policy_gradient import DDPG
from reinforcement_learning.utils.memory import Memory, Transition
from reinforcement_learning.env.arm import Arm

import torch
import os

# %%
EPISODES = 1000
STEPS = 200
BATCH_SIZE = 32

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
env = Arm()

s_dim = env.observation_dim
a_dim = env.action_dim
a_bound = env.action_space

model = DDPG(a_dim, s_dim, a_bound, 0.9, 0.01)
memory = Memory(30000)

# %%
def train():
    if os.path.isfile("./models/rl-ddpg-arm.tar"):
        model.load("./models/rl-ddpg-arm.tar")
    for i in range(EPISODES):
        score = 0
        value_loss, policy_loss = 0, 0
        state = torch.Tensor([env.reset()]).to(device)
        for j in range(STEPS):
            # env.render()
            action = model.predict(state)
            next_state, reward, done = env.step(action.cpu().numpy()[0])
            score += reward
            mask = torch.Tensor([done]).to(device)
            reward = torch.Tensor([reward]).to(device)
            next_state = torch.Tensor([next_state]).to(device)
            memory.push(state, action, mask, next_state, reward)
            state = next_state
            if len(memory) > BATCH_SIZE:
                transitions = memory.sample(BATCH_SIZE)
                batch = Transition(*zip(*transitions))
                value_loss, policy_loss = model.train(batch)
            if done:
                break
        if done:
            model.save("./models/rl-ddpg-arm.tar")
        print('Episode %d:%s Critic Loss %.2f, Action Loss %.2f' % (i+1, ' Finished Step %d,' % (j+1) if done else '', value_loss, policy_loss))

# %%
def test():
    model.load("./models/rl-ddpg-arm.tar")
    for _ in range(10):
        state = torch.Tensor([env.reset()]).to(device)
        while True:
            env.render()
            action = model.predict(state)
            next_state, reward, done = env.step(action.cpu().numpy()[0])
            state = torch.Tensor([next_state]).to(device)
            if done:
                break

# %%
train()
# Out:
# -0.19
# Episode 659: Critic Loss 0.01, Action Loss -0.28
# Episode 660: Critic Loss 0.00, Action Loss -0.15
# Episode 661: Finished Step 51, Critic Loss 0.03, Action Loss -0.34
# Episode 662: Finished Step 83, Critic Loss 0.04, Action Loss -0.29
# Episode 663: Finished Step 96, Critic Loss 0.00, Action Loss -0.10
# Episode 664: Critic Loss 0.04, Action Loss -0.44
# Episode 665: Finished Step 114, Critic Loss 0.02, Action Loss -0.16
# Episode 666: Critic Loss 0.01, Action Loss -0.48
# Episode 667: Finished Step 54, Critic Loss 0.02, Action Loss -0.20
# Episode 668: Critic Loss 0.00, Action Loss -0.31
# Episode 669: Finished Step 101, Critic Loss 0.01, Action Loss -0.34
# Episode 670: Critic Loss 0.00, Action Loss -0.40
# Episode 671: Finished Step 60, Critic Loss 0.01, Action Loss -0.44
# Episode 672: Finished Step 78, Critic Loss 0.01, Action Loss -0.20
# Episode 673: Critic Loss 0.05, Action Loss -0.49
# Episode 674: Critic Loss 0.00, Action Loss -0.12
# Episode 675: Finished Step 101, Critic Loss 0.00, Action Loss -0.21
# Episode 676: Finished Step 139, Critic Loss 0.03, Action Loss -0.28
# Episode 677: Critic Loss 0.03, Action Loss -0.31
# Episode 678: Critic Loss 0.00, Action Loss -0.29
# Episode 679: Finished Step 162, Critic Loss 0.03, Action Loss -0.36
# Episode 680: Critic Loss 0.01, Action Loss -0.44
# Episode 681: Critic Loss 0.01, Action Loss -0.49
# Episode 682: Critic Loss 0.01, Action Loss -0.21
# Episode 683: Finished Step 64, Critic Loss 0.00, Action Loss -0.28
# Episode 684: Critic Loss 0.04, Action Loss -0.17
# Episode 685: Critic Loss 0.01, Action Loss -0.25
# Episode 686: Critic Loss 0.01, Action Loss -0.11
# Episode 687: Finished Step 75, Critic Loss 0.01, Action Loss -0.49
# Episode 688: Finished Step 63, Critic Loss 0.06, Action Loss -0.45
# Episode 689: Critic Loss 0.03, Action Loss -0.43
# Episode 690: Finished Step 62, Critic Loss 0.06, Action Loss -0.27
# Episode 691: Finished Step 106, Critic Loss 0.01, Action Loss -0.27
# Episode 692: Finished Step 56, Critic Loss 0.01, Action Loss -0.38
# Episode 693: Finished Step 81, Critic Loss 0.01, Action Loss -0.31
# Episode 694: Critic Loss 0.02, Action Loss -0.31
# Episode 695: Critic Loss 0.02, Action Loss -0.30
# Episode 696: Finished Step 65, Critic Loss 0.03, Action Loss -0.19
# Episode 697: Critic Loss 0.04, Action Loss -0.48
# Episode 698: Critic Loss 0.06, Action Loss -0.42
# Episode 699: Critic Loss 0.01, Action Loss -0.25
# Episode 700: Critic Loss 0.03, Action Loss -0.23
# Episode 701: Critic Loss 0.02, Action Loss -0.37
# Episode 702: Critic Loss 0.01, Action Loss -0.29
# Episode 703: Critic Loss 0.02, Action Loss -0.36
# Episode 704: Critic Loss 0.00, Action Loss -0.18
# Episode 705: Finished Step 67, Critic Loss 0.03, Action Loss -0.42
# Episode 706: Finished Step 85, Critic Loss 0.00, Action Loss -0.24
# Episode 707: Critic Loss 0.04, Action Loss -0.32
# Episode 708: Critic Loss 0.04, Action Loss -0.59
# Episode 709: Critic Loss 0.02, Action Loss -0.45
# Episode 710: Finished Step 69, Critic Loss 0.02, Action Loss -0.37
# Episode 711: Critic Loss 0.03, Action Loss -0.36
# Episode 712: Finished Step 130, Critic Loss 0.10, Action Loss -0.35
# Episode 713: Critic Loss 0.06, Action Loss -0.25
# Episode 714: Finished Step 60, Critic Loss 0.00, Action Loss -0.33
# Episode 715: Critic Loss 0.01, Action Loss -0.30
# Episode 716: Finished Step 124, Critic Loss 0.01, Action Loss -0.35
# Episode 717: Finished Step 65, Critic Loss 0.01, Action Loss -0.27
# Episode 718: Critic Loss 0.06, Action Loss -0.28
# Episode 719: Critic Loss 0.01, Action Loss -0.23
# Episode 720: Finished Step 86, Critic Loss 0.00, Action Loss -0.19
# Episode 721: Finished Step 67, Critic Loss 0.03, Action Loss -0.46
# Episode 722: Critic Loss 0.01, Action Loss -0.58
# Episode 723: Critic Loss 0.01, Action Loss -0.36
# Episode 724: Critic Loss 0.03, Action Loss -0.39
# Episode 725: Finished Step 103, Critic Loss 0.05, Action Loss -0.51
# Episode 726: Finished Step 166, Critic Loss 0.00, Action Loss -0.19
# Episode 727: Critic Loss 0.00, Action Loss -0.18
# Episode 728: Critic Loss 0.02, Action Loss -0.32
# Episode 729: Finished Step 65, Critic Loss 0.03, Action Loss -0.51
# Episode 730: Finished Step 51, Critic Loss 0.00, Action Loss -0.44
# Episode 731: Critic Loss 0.04, Action Loss -0.31
# Episode 732: Critic Loss 0.04, Action Loss -0.59
# Episode 733: Finished Step 56, Critic Loss 0.02, Action Loss 0.01
# Episode 734: Critic Loss 0.00, Action Loss -0.21
# Episode 735: Critic Loss 0.01, Action Loss -0.35
# Episode 736: Critic Loss 0.04, Action Loss -0.14
# Episode 737: Finished Step 65, Critic Loss 0.00, Action Loss -0.06
# Episode 738: Critic Loss 0.01, Action Loss -0.39
# Episode 739: Finished Step 51, Critic Loss 0.00, Action Loss -0.42
# Episode 740: Critic Loss 0.00, Action Loss -0.38
# Episode 741: Finished Step 172, Critic Loss 0.00, Action Loss -0.31
# Episode 742: Critic Loss 0.01, Action Loss -0.30
# Episode 743: Critic Loss 0.01, Action Loss -0.20
# Episode 744: Critic Loss 0.04, Action Loss -0.34
# Episode 745: Critic Loss 0.01, Action Loss -0.34
# Episode 746: Critic Loss 0.03, Action Loss -0.28
# Episode 747: Critic Loss 0.01, Action Loss -0.19
# Episode 748: Finished Step 55, Critic Loss 0.01, Action Loss -0.31
# Episode 749: Finished Step 80, Critic Loss 0.03, Action Loss -0.20
# Episode 750: Finished Step 84, Critic Loss 0.01, Action Loss -0.42
# Episode 751: Finished Step 75, Critic Loss 0.01, Action Loss -0.29
# Episode 752: Finished Step 64, Critic Loss 0.00, Action Loss -0.11
# Episode 753: Finished Step 64, Critic Loss 0.00, Action Loss -0.40
# Episode 754: Critic Loss 0.02, Action Loss -0.16
# Episode 755: Critic Loss 0.00, Action Loss -0.38
# Episode 756: Critic Loss 0.04, Action Loss -0.27
# Episode 757: Finished Step 62, Critic Loss 0.02, Action Loss -0.24
# Episode 758: Finished Step 105, Critic Loss 0.03, Action Loss -0.27
# Episode 759: Finished Step 122, Critic Loss 0.00, Action Loss -0.18
# Episode 760: Critic Loss 0.08, Action Loss -0.27
# Episode 761: Critic Loss 0.02, Action Loss -0.25
# Episode 762: Critic Loss 0.01, Action Loss -0.35
# Episode 763: Critic Loss 0.00, Action Loss -0.24
# Episode 764: Critic Loss 0.01, Action Loss -0.09
# Episode 765: Finished Step 81, Critic Loss 0.04, Action Loss -0.24
# Episode 766: Critic Loss 0.00, Action Loss -0.41
# Episode 767: Critic Loss 0.02, Action Loss -0.38
# Episode 768: Critic Loss 0.02, Action Loss -0.26
# Episode 769: Critic Loss 0.01, Action Loss -0.37
# Episode 770: Critic Loss 0.03, Action Loss -0.31
# Episode 771: Critic Loss 0.00, Action Loss -0.42
# Episode 772: Critic Loss 0.00, Action Loss -0.22
# Episode 773: Finished Step 91, Critic Loss 0.00, Action Loss -0.53
# Episode 774: Finished Step 66, Critic Loss 0.04, Action Loss -0.51
# Episode 775: Finished Step 88, Critic Loss 0.00, Action Loss -0.29
# Episode 776: Critic Loss 0.03, Action Loss -0.30
# Episode 777: Critic Loss 0.01, Action Loss -0.23
# Episode 778: Finished Step 59, Critic Loss 0.07, Action Loss -0.43
# Episode 779: Critic Loss 0.03, Action Loss -0.36
# Episode 780: Finished Step 101, Critic Loss 0.02, Action Loss -0.39
# Episode 781: Finished Step 65, Critic Loss 0.05, Action Loss -0.42
# Episode 782: Finished Step 59, Critic Loss 0.00, Action Loss -0.37
# Episode 783: Critic Loss 0.02, Action Loss -0.30
# Episode 784: Finished Step 58, Critic Loss 0.01, Action Loss -0.22
# Episode 785: Critic Loss 0.05, Action Loss -0.27
# Episode 786: Critic Loss 0.00, Action Loss -0.17
# Episode 787: Finished Step 70, Critic Loss 0.01, Action Loss -0.37
# Episode 788: Finished Step 73, Critic Loss 0.01, Action Loss -0.26
# Episode 789: Critic Loss 0.00, Action Loss -0.10
# Episode 790: Critic Loss 0.02, Action Loss -0.45
# Episode 791: Finished Step 54, Critic Loss 0.03, Action Loss -0.30
# Episode 792: Critic Loss 0.02, Action Loss -0.34
# Episode 793: Finished Step 55, Critic Loss 0.00, Action Loss -0.25
# Episode 794: Finished Step 65, Critic Loss 0.00, Action Loss -0.38
# Episode 795: Finished Step 77, Critic Loss 0.03, Action Loss -0.40
# Episode 796: Critic Loss 0.03, Action Loss -0.33
# Episode 797: Finished Step 60, Critic Loss 0.02, Action Loss -0.59
# Episode 798: Critic Loss 0.03, Action Loss -0.20
# Episode 799: Finished Step 66, Critic Loss 0.06, Action Loss -0.52
# Episode 800: Finished Step 156, Critic Loss 0.00, Action Loss -0.29
# Episode 801: Finished Step 154, Critic Loss 0.01, Action Loss -0.23
# Episode 802: Finished Step 93, Critic Loss 0.02, Action Loss -0.44
# Episode 803: Critic Loss 0.02, Action Loss -0.29
# Episode 804: Critic Loss 0.01, Action Loss -0.32
# Episode 805: Finished Step 68, Critic Loss 0.03, Action Loss -0.31
# Episode 806: Finished Step 67, Critic Loss 0.04, Action Loss -0.64
# Episode 807: Critic Loss 0.04, Action Loss -0.33
# Episode 808: Finished Step 103, Critic Loss 0.05, Action Loss -0.38
# Episode 809: Critic Loss 0.01, Action Loss -0.36
# Episode 810: Finished Step 58, Critic Loss 0.00, Action Loss -0.22
# Episode 811: Critic Loss 0.04, Action Loss -0.28
# Episode 812: Finished Step 77, Critic Loss 0.01, Action Loss -0.29
# Episode 813: Finished Step 73, Critic Loss 0.01, Action Loss -0.36
# Episode 814: Critic Loss 0.01, Action Loss -0.30
# Episode 815: Finished Step 72, Critic Loss 0.02, Action Loss -0.29
# Episode 816: Critic Loss 0.01, Action Loss -0.35
# Episode 817: Finished Step 88, Critic Loss 0.01, Action Loss -0.38
# Episode 818: Finished Step 81, Critic Loss 0.00, Action Loss -0.26
# Episode 819: Finished Step 54, Critic Loss 0.01, Action Loss -0.52
# Episode 820: Critic Loss 0.05, Action Loss -0.50
# Episode 821: Critic Loss 0.03, Action Loss -0.41
# Episode 822: Finished Step 59, Critic Loss 0.01, Action Loss -0.32
# Episode 823: Critic Loss 0.01, Action Loss -0.12
# Episode 824: Critic Loss 0.01, Action Loss -0.19
# Episode 825: Critic Loss 0.00, Action Loss -0.42
# Episode 826: Finished Step 91, Critic Loss 0.02, Action Loss -0.50
# Episode 827: Critic Loss 0.03, Action Loss -0.36
# Episode 828: Critic Loss 0.00, Action Loss -0.27
# Episode 829: Critic Loss 0.02, Action Loss -0.39
# Episode 830: Finished Step 104, Critic Loss 0.00, Action Loss -0.30
# Episode 831: Critic Loss 0.01, Action Loss -0.18
# Episode 832: Finished Step 53, Critic Loss 0.02, Action Loss -0.41
# Episode 833: Finished Step 67, Critic Loss 0.02, Action Loss -0.32
# Episode 834: Finished Step 66, Critic Loss 0.02, Action Loss -0.33
# Episode 835: Critic Loss 0.05, Action Loss -0.44
# Episode 836: Finished Step 75, Critic Loss 0.00, Action Loss -0.14
# Episode 837: Finished Step 57, Critic Loss 0.03, Action Loss -0.25
# Episode 838: Critic Loss 0.01, Action Loss -0.31
# Episode 839: Finished Step 66, Critic Loss 0.06, Action Loss -0.38
# Episode 840: Critic Loss 0.01, Action Loss -0.32
# Episode 841: Finished Step 115, Critic Loss 0.04, Action Loss -0.22
# Episode 842: Critic Loss 0.01, Action Loss -0.43
# Episode 843: Finished Step 79, Critic Loss 0.04, Action Loss -0.40
# Episode 844: Finished Step 81, Critic Loss 0.04, Action Loss -0.45
# Episode 845: Critic Loss 0.01, Action Loss -0.28
# Episode 846: Finished Step 182, Critic Loss 0.06, Action Loss -0.47
# Episode 847: Critic Loss 0.03, Action Loss -0.47
# Episode 848: Finished Step 93, Critic Loss 0.04, Action Loss -0.47
# Episode 849: Finished Step 60, Critic Loss 0.00, Action Loss -0.31
# Episode 850: Finished Step 194, Critic Loss 0.04, Action Loss -0.40
# Episode 851: Finished Step 70, Critic Loss 0.02, Action Loss -0.49
# Episode 852: Finished Step 101, Critic Loss 0.01, Action Loss -0.40
# Episode 853: Finished Step 65, Critic Loss 0.04, Action Loss -0.39
# Episode 854: Finished Step 75, Critic Loss 0.01, Action Loss -0.25
# Episode 855: Finished Step 52, Critic Loss 0.04, Action Loss -0.46
# Episode 856: Finished Step 52, Critic Loss 0.00, Action Loss -0.48
# Episode 857: Finished Step 107, Critic Loss 0.01, Action Loss -0.37
# Episode 858: Finished Step 54, Critic Loss 0.05, Action Loss -0.45
# Episode 859: Critic Loss 0.01, Action Loss -0.31
# Episode 860: Critic Loss 0.03, Action Loss -0.31
# Episode 861: Finished Step 117, Critic Loss 0.04, Action Loss -0.30
# Episode 862: Critic Loss 0.01, Action Loss -0.34
# Episode 863: Finished Step 97, Critic Loss 0.03, Action Loss -0.40
# Episode 864: Critic Loss 0.04, Action Loss -0.33
# Episode 865: Finished Step 59, Critic Loss 0.02, Action Loss -0.26
# Episode 866: Finished Step 114, Critic Loss 0.02, Action Loss -0.34
# Episode 867: Critic Loss 0.03, Action Loss -0.43
# Episode 868: Finished Step 80, Critic Loss 0.00, Action Loss -0.22
# Episode 869: Finished Step 60, Critic Loss 0.01, Action Loss -0.28
# Episode 870: Critic Loss 0.03, Action Loss -0.50
# Episode 871: Critic Loss 0.08, Action Loss -0.46
# Episode 872: Critic Loss 0.01, Action Loss -0.31
# Episode 873: Critic Loss 0.06, Action Loss -0.46
# Episode 874: Finished Step 67, Critic Loss 0.01, Action Loss -0.32
# Episode 875: Critic Loss 0.03, Action Loss -0.24
# Episode 876: Critic Loss 0.00, Action Loss -0.37
# Episode 877: Finished Step 80, Critic Loss 0.02, Action Loss -0.42
# Episode 878: Finished Step 60, Critic Loss 0.03, Action Loss -0.47
# Episode 879: Critic Loss 0.03, Action Loss -0.28
# Episode 880: Finished Step 63, Critic Loss 0.01, Action Loss -0.41
# Episode 881: Finished Step 68, Critic Loss 0.01, Action Loss -0.33
# Episode 882: Finished Step 145, Critic Loss 0.00, Action Loss -0.35
# Episode 883: Finished Step 71, Critic Loss 0.06, Action Loss -0.31
# Episode 884: Finished Step 64, Critic Loss 0.02, Action Loss -0.32
# Episode 885: Finished Step 105, Critic Loss 0.02, Action Loss -0.41
# Episode 886: Finished Step 72, Critic Loss 0.05, Action Loss -0.37
# Episode 887: Finished Step 87, Critic Loss 0.10, Action Loss -0.63
# Episode 888: Critic Loss 0.02, Action Loss -0.38
# Episode 889: Finished Step 78, Critic Loss 0.04, Action Loss -0.38
# Episode 890: Finished Step 85, Critic Loss 0.01, Action Loss -0.38
# Episode 891: Critic Loss 0.02, Action Loss -0.40
# Episode 892: Finished Step 59, Critic Loss 0.03, Action Loss -0.46
# Episode 893: Finished Step 72, Critic Loss 0.02, Action Loss -0.67
# Episode 894: Critic Loss 0.02, Action Loss -0.43
# Episode 895: Finished Step 80, Critic Loss 0.02, Action Loss -0.59
# Episode 896: Critic Loss 0.01, Action Loss -0.54
# Episode 897: Finished Step 64, Critic Loss 0.00, Action Loss -0.39
# Episode 898: Critic Loss 0.04, Action Loss -0.45
# Episode 899: Finished Step 68, Critic Loss 0.01, Action Loss -0.44
# Episode 900: Finished Step 76, Critic Loss 0.00, Action Loss -0.46
# Episode 901: Finished Step 82, Critic Loss 0.00, Action Loss -0.12
# Episode 902: Critic Loss 0.01, Action Loss -0.61
# Episode 903: Finished Step 75, Critic Loss 0.05, Action Loss -0.37
# Episode 904: Finished Step 98, Critic Loss 0.02, Action Loss -0.38
# Episode 905: Finished Step 71, Critic Loss 0.01, Action Loss -0.44
# Episode 906: Critic Loss 0.03, Action Loss -0.55
# Episode 907: Finished Step 51, Critic Loss 0.03, Action Loss -0.41
# Episode 908: Finished Step 81, Critic Loss 0.01, Action Loss -0.47
# Episode 909: Critic Loss 0.05, Action Loss -0.45
# Episode 910: Finished Step 79, Critic Loss 0.02, Action Loss -0.52
# Episode 911: Finished Step 94, Critic Loss 0.03, Action Loss -0.38
# Episode 912: Finished Step 59, Critic Loss 0.00, Action Loss -0.42
# Episode 913: Critic Loss 0.01, Action Loss -0.48
# Episode 914: Finished Step 62, Critic Loss 0.04, Action Loss -0.48
# Episode 915: Critic Loss 0.04, Action Loss -0.56
# Episode 916: Finished Step 85, Critic Loss 0.06, Action Loss -0.35
# Episode 917: Finished Step 80, Critic Loss 0.01, Action Loss -0.46
# Episode 918: Critic Loss 0.01, Action Loss -0.17
# Episode 919: Finished Step 61, Critic Loss 0.01, Action Loss -0.30
# Episode 920: Finished Step 137, Critic Loss 0.01, Action Loss -0.35
# Episode 921: Critic Loss 0.03, Action Loss -0.32
# Episode 922: Critic Loss 0.01, Action Loss -0.48
# Episode 923: Finished Step 73, Critic Loss 0.03, Action Loss -0.64
# Episode 924: Finished Step 76, Critic Loss 0.03, Action Loss -0.58
# Episode 925: Finished Step 58, Critic Loss 0.01, Action Loss -0.31
# Episode 926: Finished Step 68, Critic Loss 0.04, Action Loss -0.47
# Episode 927: Finished Step 80, Critic Loss 0.05, Action Loss -0.57
# Episode 928: Finished Step 90, Critic Loss 0.00, Action Loss -0.19
# Episode 929: Finished Step 140, Critic Loss 0.01, Action Loss -0.48
# Episode 930: Critic Loss 0.06, Action Loss -0.38
# Episode 931: Finished Step 128, Critic Loss 0.03, Action Loss -0.39
# Episode 932: Critic Loss 0.03, Action Loss -0.41
# Episode 933: Finished Step 95, Critic Loss 0.07, Action Loss -0.27
# Episode 934: Critic Loss 0.01, Action Loss -0.57
# Episode 935: Finished Step 64, Critic Loss 0.02, Action Loss -0.47
# Episode 936: Critic Loss 0.02, Action Loss -0.70
# Episode 937: Critic Loss 0.09, Action Loss -0.58
# Episode 938: Critic Loss 0.04, Action Loss -0.43
# Episode 939: Finished Step 70, Critic Loss 0.01, Action Loss -0.42
# Episode 940: Finished Step 63, Critic Loss 0.02, Action Loss -0.62
# Episode 941: Finished Step 74, Critic Loss 0.01, Action Loss -0.33
# Episode 942: Finished Step 151, Critic Loss 0.03, Action Loss -0.49
# Episode 943: Finished Step 56, Critic Loss 0.01, Action Loss -0.63
# Episode 944: Finished Step 84, Critic Loss 0.02, Action Loss -0.41
# Episode 945: Finished Step 88, Critic Loss 0.04, Action Loss -0.63
# Episode 946: Finished Step 99, Critic Loss 0.03, Action Loss -0.45
# Episode 947: Critic Loss 0.13, Action Loss -0.39
# Episode 948: Critic Loss 0.03, Action Loss -0.47
# Episode 949: Critic Loss 0.01, Action Loss -0.40
# Episode 950: Critic Loss 0.02, Action Loss -0.59
# Episode 951: Critic Loss 0.01, Action Loss -0.24
# Episode 952: Finished Step 92, Critic Loss 0.00, Action Loss -0.49
# Episode 953: Critic Loss 0.02, Action Loss -0.50
# Episode 954: Critic Loss 0.02, Action Loss -0.63
# Episode 955: Critic Loss 0.03, Action Loss -0.48
# Episode 956: Finished Step 85, Critic Loss 0.03, Action Loss -0.56
# Episode 957: Critic Loss 0.02, Action Loss -0.37
# Episode 958: Critic Loss 0.00, Action Loss -0.49
# Episode 959: Critic Loss 0.08, Action Loss -0.56
# Episode 960: Finished Step 73, Critic Loss 0.00, Action Loss -0.39
# Episode 961: Finished Step 61, Critic Loss 0.01, Action Loss -0.16
# Episode 962: Finished Step 70, Critic Loss 0.00, Action Loss -0.34
# Episode 963: Finished Step 88, Critic Loss 0.02, Action Loss -0.35
# Episode 964: Critic Loss 0.10, Action Loss -0.48
# Episode 965: Finished Step 69, Critic Loss 0.03, Action Loss -0.39
# Episode 966: Critic Loss 0.02, Action Loss -0.47
# Episode 967: Critic Loss 0.02, Action Loss -0.53
# Episode 968: Critic Loss 0.02, Action Loss -0.44
# Episode 969: Critic Loss 0.01, Action Loss -0.26
# Episode 970: Critic Loss 0.04, Action Loss -0.36
# Episode 971: Finished Step 84, Critic Loss 0.04, Action Loss -0.64
# Episode 972: Finished Step 53, Critic Loss 0.02, Action Loss -0.35
# Episode 973: Critic Loss 0.00, Action Loss -0.46
# Episode 974: Finished Step 84, Critic Loss 0.01, Action Loss -0.56
# Episode 975: Finished Step 61, Critic Loss 0.00, Action Loss -0.35
# Episode 976: Critic Loss 0.02, Action Loss -0.27
# Episode 977: Critic Loss 0.09, Action Loss -0.37
# Episode 978: Finished Step 62, Critic Loss 0.02, Action Loss -0.63
# Episode 979: Critic Loss 0.04, Action Loss -0.52
# Episode 980: Critic Loss 0.03, Action Loss -0.57
# Episode 981: Finished Step 70, Critic Loss 0.02, Action Loss -0.42
# Episode 982: Critic Loss 0.03, Action Loss -0.41
# Episode 983: Critic Loss 0.10, Action Loss -0.58
# Episode 984: Critic Loss 0.04, Action Loss -0.48
# Episode 985: Critic Loss 0.01, Action Loss -0.36
# Episode 986: Critic Loss 0.01, Action Loss -0.30
# Episode 987: Critic Loss 0.01, Action Loss -0.42
# Episode 988: Finished Step 52, Critic Loss 0.03, Action Loss -0.36
# Episode 989: Finished Step 57, Critic Loss 0.01, Action Loss -0.41
# Episode 990: Critic Loss 0.03, Action Loss -0.55
# Episode 991: Critic Loss 0.03, Action Loss -0.42
# Episode 992: Finished Step 81, Critic Loss 0.01, Action Loss -0.24
# Episode 993: Critic Loss 0.01, Action Loss -0.41
# Episode 994: Finished Step 190, Critic Loss 0.02, Action Loss -0.57
# Episode 995: Finished Step 65, Critic Loss 0.06, Action Loss -0.45
# Episode 996: Finished Step 72, Critic Loss 0.01, Action Loss -0.20
# Episode 997: Finished Step 91, Critic Loss 0.02, Action Loss -0.37
# Episode 998: Critic Loss 0.03, Action Loss -0.41
# Episode 999: Finished Step 95, Critic Loss 0.01, Action Loss -0.31
# Episode 1000: Finished Step 90, Critic Loss 0.01, Action Loss -0.54

# %%
test()
